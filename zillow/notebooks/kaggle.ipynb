# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/fangjie/Downloads/properties_2016.csv',nrows=100)

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
df.describe
# Out:
# <bound method DataFrame.describe of     parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0   10754147                    NaN                       NaN           NaN
# 1   10759547                    NaN                       NaN           NaN
# 2   10843547                    NaN                       NaN           NaN
# 3   10859147                    NaN                       NaN           NaN
# 4   10879947                    NaN                       NaN           NaN
# 5   10898347                    NaN                       NaN           NaN
# 6   10933547                    NaN                       NaN           NaN
# 7   10940747                    NaN                       NaN           NaN
# 8   10954547                    NaN                       NaN           NaN
# 9   10976347                    NaN                       NaN           NaN
# 10  11073947                    NaN                       NaN           NaN
# ...
